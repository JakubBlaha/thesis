# %%
# %matplotlib qt
import mne, os, glob, pandas as pd, re

clean = glob.glob("../data/segmented/*/clean/*-epo.fif")
dirty = [path.replace("clean", "raw") for path in clean]

zipped = list(zip(dirty, clean))

d = {"fnames": [], "pre": [], "post": [], "removed": [], "dur": []}

for pre_ar_path, post_ar_path in zipped:
    pre = mne.read_epochs(pre_ar_path)
    post = mne.read_epochs(post_ar_path)

    d["fnames"].append(pre_ar_path)
    d["pre"].append(len(pre))
    d["post"].append(len(post))
    d["removed"].append(len(pre) - len(post))

    duration = re.search(r"/(\d+)s/", pre_ar_path).group(1)
    duration = int(duration)
    d["dur"].append(duration)


df = pd.DataFrame(d)

df
# Out:
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S10-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S10-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 17 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S19-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S19-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S09-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S09-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S08-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S08-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S18-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S18-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S11-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S11-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S01-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S01-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 17 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S03-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S03-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S13-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S13-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S12-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S12-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S02-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S02-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 14 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S21-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S21-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S07-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S07-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S17-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S17-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S16-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S16-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 8 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S06-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S06-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 14 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S20-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S20-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S04-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S04-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S14-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S14-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S22-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S22-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 14 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S23-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S23-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 13 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S15-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S15-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/raw/S05-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/segmented/10s/clean/S05-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 13 matching events found
# No baseline correction applied
# 0 projection items activated
#                                    fnames  pre  post  removed  dur
# 0   ../data/segmented/10s/raw/S10-epo.fif   18    17        1   10
# 1   ../data/segmented/10s/raw/S19-epo.fif   18    18        0   10
# 2   ../data/segmented/10s/raw/S09-epo.fif   18    18        0   10
# 3   ../data/segmented/10s/raw/S08-epo.fif   18    18        0   10
# 4   ../data/segmented/10s/raw/S18-epo.fif   18    18        0   10
# 5   ../data/segmented/10s/raw/S11-epo.fif   18    15        3   10
# 6   ../data/segmented/10s/raw/S01-epo.fif   18    17        1   10
# 7   ../data/segmented/10s/raw/S03-epo.fif   18    18        0   10
# 8   ../data/segmented/10s/raw/S13-epo.fif   18    18        0   10
# 9   ../data/segmented/10s/raw/S12-epo.fif   18    18        0   10
# 10  ../data/segmented/10s/raw/S02-epo.fif   18    14        4   10
# 11  ../data/segmented/10s/raw/S21-epo.fif   18    18        0   10
# 12  ../data/segmented/10s/raw/S07-epo.fif   18    18        0   10
# 13  ../data/segmented/10s/raw/S17-epo.fif   18    15        3   10
# 14  ../data/segmented/10s/raw/S16-epo.fif   18     8       10   10
# 15  ../data/segmented/10s/raw/S06-epo.fif   18    14        4   10
# 16  ../data/segmented/10s/raw/S20-epo.fif   18    18        0   10
# 17  ../data/segmented/10s/raw/S04-epo.fif   18    18        0   10
# 18  ../data/segmented/10s/raw/S14-epo.fif   18    18        0   10
# 19  ../data/segmented/10s/raw/S22-epo.fif   18    14        4   10
# 20  ../data/segmented/10s/raw/S23-epo.fif   18    13        5   10
# 21  ../data/segmented/10s/raw/S15-epo.fif   18    18        0   10
# 22  ../data/segmented/10s/raw/S05-epo.fif   18    13        5   10

# %%
def print_stats_for_dur(seconds):
    df_filt = df[df["dur"] == seconds]

    total_pre = df_filt["pre"].sum()
    total_post = df_filt["post"].sum()
    total_removed = df_filt["removed"].sum()

    print(f"Total pre: {total_pre}")
    print(f"Total post: {total_post}")
    print(f"Total removed: {total_removed}")
    print(f"Removed: {total_removed / total_pre * 100:.2f}%")

print_stats_for_dur(10)
# Out:
# Total pre: 414
# Total post: 374
# Total removed: 40
# Removed: 9.66%

# %%
viz = zipped[0]

pre = mne.read_epochs(viz[0])
post = mne.read_epochs(viz[1])

# pre.plot(scalings=100)
# post.plot(scalings=100)

post.metadata
# Out:
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/fif/S10_seg_10s-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jakubblaha/Documents/thesis/thesis-python/notebooks/../data/fif/S10_seg_10s_clean-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    9992.19 ms
#         0 CTF compensation matrices available
# Adding metadata with 4 columns
# 17 matching events found
# No baseline correction applied
# 0 projection items activated
#     subject dataset ham  SAM
# 0        10   dasps  LA    0
# 1        10   dasps  LA    0
# 2        10   dasps  LA    0
# 3        10   dasps  LA    0
# 4        10   dasps  LA    0
# 5        10   dasps  LA    0
# 6        10   dasps  LA    0
# 8        10   dasps  LA    0
# 9        10   dasps  LA    0
# 10       10   dasps  LA    0
# 11       10   dasps  LA    0
# 12       10   dasps  LA    0
# 13       10   dasps  LA    0
# 14       10   dasps  LA    0
# 15       10   dasps  LA    0
# 16       10   dasps  LA    0
# 17       10   dasps  LA    0
